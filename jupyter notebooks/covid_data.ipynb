# %%
import csv
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
print('modules have been installed')
# Out:
# modules have been installed

# %%
with open('BCCase_Details.csv', mode='r') as csvfile:
    data = csv.reader(csvfile, delimiter=',')
    for row in data:
        print(row[0:5])
# Out:
# , 'Fraser', 'F', '30-39', 'Lab-diagnosed']
# ['22/11/20', 'Fraser', 'F', '40-49', 'Lab-diagnosed']
# ['22/11/20', 'Fraser', 'M', '30-39', 'Lab-diagnosed']
# ['22/11/20', 'Fraser', 'M', '20-29', 'Lab-diagnosed']
# ['22/11/20', 'Fraser', 'M', 'Oct-19', 'Lab-diagnosed']
# ['22/11/20', 'Fraser', 'M', '30-39', 'Lab-diagnosed']
# ['22/11/20', 'Fraser', 'M', '30-39', 'Lab-diagnosed']
# ['22/11/20', 'Fraser', 'F', '20-29', 'Lab-diagnosed']
# ['22/11/20', 'Fraser', 'F', '20-29', 'Lab-diagnosed']
# ['22/11/20', 'Fraser', 'M', '30-39', 'Lab-diagnosed']
# ['22/11/20', 'Fraser', 'M', '90+', 'Lab-diagnosed']
# ['22/11/20', 'Fraser', 'F', '50-59', 'Lab-diagnosed']
# ['22/11/20', 'Fraser', 'F', '30-39', 'Lab-diagnosed']
# ['22/11/20', 'Fraser', 'M', '30-39', 'Lab-diagnosed']
# ['22/11/20', 'Fraser', 'F', '40-49', 'Lab-diagnosed']
# ['22/11/20', 'Fraser', 'F', '60-69', 'Lab-diagnosed']
# ['22/11/20', 'Fraser', 'F', '40-49', 'Lab-diagnosed']
# ['22/11/20', 'Fraser', 'M', '60-69', 'Lab-diagnosed']
# ...
